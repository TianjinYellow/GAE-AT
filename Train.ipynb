# %%
# %cd /content/drive/MyDrive/ECML/Graph\ Anomaly\ Detection/gae-pytorch-master/gae
# Out:
# /content/drive/MyDrive/ECML/Graph Anomaly Detection/gae-pytorch-master/gae

# %%
# !pip install -q torch-scatter -f https://pytorch-geometric.com/whl/torch-1.8.0+cu101.html
# !pip install -q torch-sparse -f https://pytorch-geometric.com/whl/torch-1.8.0+cu101.html
# !pip install -q torch-geometric
# !pip install -q munkres

# %% [markdown]
# #Link Prediction

# %%
# !python ./AT_Link_prediction.py --perturbStyle "alternative" --dataset "Cora" --RepeatRuns 10 --epsSt 1e-3 --epsFeat 5e-1 --norm l2 --lam 4 --epochs 600
# Out:
# perturbation Style: alternative
# Repeats number: 0
# Epoch: 100, Val AUC: 0.9081, Val AP: 0.8895, Test AUC: 0.9125, Test AP: 0.9072
# Epoch: 200, Val AUC: 0.9294, Val AP: 0.9292, Test AUC: 0.9264, Test AP: 0.9292
# Epoch: 300, Val AUC: 0.9318, Val AP: 0.9323, Test AUC: 0.9279, Test AP: 0.9329
# Epoch: 400, Val AUC: 0.9320, Val AP: 0.9342, Test AUC: 0.9314, Test AP: 0.9385
# Epoch: 500, Val AUC: 0.9317, Val AP: 0.9370, Test AUC: 0.9309, Test AP: 0.9394
# Epoch: 600, Val AUC: 0.9305, Val AP: 0.9354, Test AUC: 0.9281, Test AP: 0.9369
# Repeats number: 1
# Epoch: 100, Val AUC: 0.9169, Val AP: 0.9110, Test AUC: 0.9220, Test AP: 0.9191
# Epoch: 200, Val AUC: 0.9228, Val AP: 0.9169, Test AUC: 0.9288, Test AP: 0.9257
# Epoch: 300, Val AUC: 0.9225, Val AP: 0.9206, Test AUC: 0.9291, Test AP: 0.9267
# Epoch: 400, Val AUC: 0.9245, Val AP: 0.9222, Test AUC: 0.9314, Test AP: 0.9287
# Epoch: 500, Val AUC: 0.9249, Val AP: 0.9229, Test AUC: 0.9316, Test AP: 0.9313
# ...

# %% [markdown]
# #Node Clustering

# %%
# !python ./AT_node_cluster.py --perturbStyle  "alternative" --dataset "Cora" --RepeatRuns 10 --epsSt 1e-3 --epsFeat 5e-1 --norm l2 --lam 4 --epochs 600
# Out:
# perturbation Style: alternative
# Repeats number: 0
# ACC=0.625185, f1_macro=0.594914, precision_macro=0.617950, recall_macro=0.610958, f1_micro=0.625185, precision_micro=0.625185, recall_micro=0.625185, NMI=0.499348, ADJ_RAND_SCORE=0.405188
# Epoch: 100, Test AUC: 0.9180, Test AP: 0.9184
# ACC=0.664328, f1_macro=0.649005, precision_macro=0.662575, recall_macro=0.683448, f1_micro=0.664328, precision_micro=0.664328, recall_micro=0.664328, NMI=0.499178, ADJ_RAND_SCORE=0.437774
# Epoch: 200, Test AUC: 0.9250, Test AP: 0.9278
# ACC=0.675406, f1_macro=0.667182, precision_macro=0.688309, recall_macro=0.698420, f1_micro=0.675406, precision_micro=0.675406, recall_micro=0.675406, NMI=0.504194, ADJ_RAND_SCORE=0.435825
# Epoch: 300, Test AUC: 0.9267, Test AP: 0.9301
# ACC=0.655465, f1_macro=0.663765, precision_macro=0.710295, recall_macro=0.679837, f1_micro=0.655465, precision_micro=0.655465, recall_micro=0.655465, NMI=0.520536, ADJ_RAND_SCORE=0.424838
# ...

# %% [markdown]
# #Graph Anomaly detection

# %%
# !python ./AT_graph_anomaly_detection.py --perturbStyle "alternative" --dataset "Flickr" --RepeatRuns 10 --epsSt 1e-6 --epsFeat 3e-1 --norm l2 --lam 5 --epochs 300
# Out:
# perturbation Style: alternative
# Repeats number: 0
# anomaly auc 0.852797171500179
# anomaly auc 0.8525166089827743
# anomaly auc 0.8501064168357403
# Repeats number: 1
# anomaly auc 0.8537068862632772
# anomaly auc 0.851472828897641
# anomaly auc 0.8532545649838883
# Repeats number: 2
# anomaly auc 0.8529438676055217
# Traceback (most recent call last):
#   File "./AT_graph_anomaly_detection.py", line 596, in <module>
#   File "./AT_graph_anomaly_detection.py", line 533, in train
#     delta=attack_features(x,model,args.steps,args.epsFeat,train_pos_edge_index,args.norm)
#   File "./AT_graph_anomaly_detection.py", line 432, in attack_features
#     loss = model.recon_loss(x,z, train_pos_edge_index)
#   File "./AT_graph_anomaly_detection.py", line 329, in recon_loss
#     neg_edge_index = negative_sampling(pos_edge_index, z.size(0))
#   File "/usr/local/lib/python3.7/dist-packages/torch_geometric/utils/negative_sampling.py", line 76, in negative_sampling
# ...
